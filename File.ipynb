# %%
import python_file
# Out:
# Running investment_score.py
# 114
#
# 고객님의 투자 성향은 공격형입니다
# 위험 자산에 최대 100%까지 투자할 수 있습니다
# Enter the portfolio date (format: YYYYMMDD) : 20220131
#
#
# 고객님의 투자 성향은 공격형입니다
# 위험 자산에 최대 100%까지 투자할 수 있습니다
#                초고위험     초저위험
# Type        해외주식ETF  해외채권ETF
# Risk Score      5.0      1.0
# Weight           95        5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>초고위험</th>
#       <th>초저위험</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Type</th>
#       <td>해외주식ETF</td>
#       <td>해외채권ETF</td>
#     </tr>
#     <tr>
#       <th>Risk Score</th>
#       <td>5.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>Weight</th>
#       <td>95</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>순위</th>
#       <th>테마</th>
#       <th>ETF</th>
#       <th>%</th>
# ...
